# %% [markdown]
# # PART A

# %%
# imports
import os
import time
import glob
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import wandb
from env import create_standard_grid, create_four_room

# Optional: configure matplotlib for notebooks
# %matplotlib inline

# %% [markdown]
# ### Create environment

# %%
all_configs = []

# -------------------------------
# 10x10 Grid World: Q-learning (8)
# -------------------------------
for tp in [0.7, 1.0]:
    for start_state in [(0, 4), (3, 6)]:
        for strat in ['eps_greedy', 'softmax']:
            name = f"std_q_tp{tp}_ss{start_state}_strat{strat}"
            cfg = {
                'name': name,
                'alg': 'q_learning',
                'env_builder': create_standard_grid,
                'env_kwargs': {
                    # ✅ FIX: convert tuple to 2D numpy array
                    'start_state': np.array([[start_state[0], start_state[1]]]),
                    'transition_prob': tp,
                    'wind': False
                },
                'strategy': strat
            }
            all_configs.append(cfg)

# -------------------------------
# 10x10 Grid World: SARSA (8)
# -------------------------------
for wind in [True, False]:
    for start_state in [(0, 4), (3, 6)]:
        for strat in ['eps_greedy', 'softmax']:
            name = f"std_sarsa_wind{wind}_ss{start_state}_strat{strat}"
            cfg = {
                'name': name,
                'alg': 'sarsa',
                'env_builder': create_standard_grid,
                'env_kwargs': {
                    # ✅ FIX here too
                    'start_state': np.array([[start_state[0], start_state[1]]]),
                    'transition_prob': 1.0,
                    'wind': wind
                },
                'strategy': strat
            }
            all_configs.append(cfg)

# -------------------------------
# Four-Room configs (no fix needed)
# -------------------------------
for goal_change in [True, False]:
    all_configs.append({
        'name': f"four_q_goalchange{goal_change}_strateps_greedy",
        'alg': 'q_learning',
        'env_builder': create_four_room,
        'env_kwargs': {'goal_change': goal_change},
        'strategy': 'eps_greedy'
    })
for goal_change in [True, False]:
    all_configs.append({
        'name': f"four_sarsa_goalchange{goal_change}_strateps_greedy",
        'alg': 'sarsa',
        'env_builder': create_four_room,
        'env_kwargs': {'goal_change': goal_change},
        'strategy': 'eps_greedy'
    })

# %% [markdown]
# ### Functions

# %%
# Safe reward scalar extractor for 1-element arrays
def reward_scalar(r):
    return float(np.ravel(r)[0])

# epsilon greedy function
# Chose to use correct datatype outputs as it becomes a problem in downstream tasks.

def epsilon_greedy_action(Q: np.ndarray, state: int, epsilon: float) -> int:
    """Pick epsilon-greedy action from Q[state]."""
    if np.random.rand() < epsilon:
        return np.random.randint(Q.shape[1])
    return int(np.argmax(Q[state]))

# --- Episode termination check ---
def is_terminal(state: int, goal_states_seq: np.ndarray) -> bool:
    return state in set(map(int, np.array(goal_states_seq).flatten()))

# --- Rollouts for evaluation ---
def evaluate_policy(env, Q: np.ndarray, episodes: int = 20, max_steps: int = 100) -> float:
    total = 0.0
    for _ in range(episodes):
        s = env.reset()
        ep_ret = 0.0
        for _ in range(max_steps):
            a = int(np.argmax(Q[s]))
            s_next, r = env.step(s, a)
            ep_ret += reward_scalar(r)
            s = int(s_next)
            if is_terminal(s, env.goal_states_seq):
                break
        total += ep_ret
    return total / episodes
    
def softmax_action(Q, state, tau):
    tau = float(tau)
    if tau <= 0:
        return int(np.argmax(Q[state]))
    z = Q[state] / tau
    z = z - np.max(z)
    p = np.exp(z)
    p = p / np.sum(p)
    return int(np.random.choice(len(p), p=p))


def select_action(Q, state, strategy, param):
    if strategy == 'eps_greedy':
        if np.random.rand() < float(param):
            return int(np.random.randint(Q.shape[1]))
        return int(np.argmax(Q[state]))
    elif strategy == 'softmax':
        return softmax_action(Q, state, float(param))
    else:
        raise ValueError('Unknown exploration strategy: ' + str(strategy))

# %% [markdown]
# ### Q-learning function

# %%
def train_q_learning_fixed(env, episodes, alpha, gamma, strategy, param, max_steps=100, run=None, seed=None):
    """
    Q-Learning with optional WandB logging.
    """
    n_states, n_actions = env.num_states, env.num_actions
    Q = np.zeros((n_states, n_actions))
    returns = []

    for ep in range(episodes):
        state = int(env.reset())
        total_reward = 0.0

        for _ in range(max_steps):
            a = select_action(Q, state, strategy, param)
            s_next, r = env.step(state, a)
            r = reward_scalar(r)
            total_reward += r
            s_next = int(s_next)

            if is_terminal(s_next, env.goal_states_seq):
                Q[state, a] += alpha * (r - Q[state, a])
                break

            td_target = r + gamma * np.max(Q[s_next])
            Q[state, a] += alpha * (td_target - Q[state, a])
            state = s_next

        returns.append(total_reward)

        # ✅ WandB logging
        if run is not None:
            wandb.log({
                "episode": ep,
                "episode_return": total_reward,
                "algorithm": "Q-learning",
                "alpha": alpha,
                "gamma": gamma,
                "param": param,
                "strategy": strategy,
                "seed": seed
            })

        if (ep + 1) % 200 == 0:
            print(f"[Q] Episode {ep+1}/{episodes} | Mean(Last50): {np.mean(returns[-50:]):.2f}")

    return Q, returns

# %% [markdown]
# ### SARSA function

# %%
def train_sarsa_fixed(env, episodes, alpha, gamma, strategy, param, max_steps=100, run=None, seed=None):
    """
    SARSA with optional WandB logging.
    """
    n_states, n_actions = env.num_states, env.num_actions
    Q = np.zeros((n_states, n_actions))
    returns = []

    for ep in range(episodes):
        s = int(env.reset())
        a = select_action(Q, s, strategy, param)
        total_reward = 0.0

        for _ in range(max_steps):
            s_next, r = env.step(s, a)
            r = reward_scalar(r)
            total_reward += r
            s_next = int(s_next)

            if is_terminal(s_next, env.goal_states_seq):
                Q[s, a] += alpha * (r - Q[s, a])
                break

            a_next = select_action(Q, s_next, strategy, param)
            td_target = r + gamma * Q[s_next, a_next]
            Q[s, a] += alpha * (td_target - Q[s, a])
            s, a = s_next, a_next

        returns.append(total_reward)

        # ✅ WandB logging
        if run is not None:
            wandb.log({
                "episode": ep,
                "episode_return": total_reward,
                "algorithm": "SARSA",
                "alpha": alpha,
                "gamma": gamma,
                "param": param,
                "strategy": strategy,
                "seed": seed
            })

        if (ep + 1) % 200 == 0:
            print(f"[SARSA] Episode {ep+1}/{episodes} | Mean(Last50): {np.mean(returns[-50:]):.2f}")

    return Q, returns

# %% [markdown]
# ### Setting up Wandb

# %%
wandb.init()

# 
sweep_config_1 = {
    'method': 'grid',   # try every combination
    'metric': {
        'name': 'mean_eval_return',
        'goal': 'maximize'
    },
    'parameters': {
        'alpha': {'values': [0.001, 0.01, 0.1, 1.0]},
        'gamma': {'values': [0.7, 0.8, 0.9, 1.0]},
        'param': {'values': [0.001, 0.01, 0.05, 0.1]},  # Use param if your code expects epsilon as "param"
        'algorithm': {'values': ['q_learning']},
        'strategy': {'values': ['eps_greedy']},
        'env_name': {'values': ['std_q_tp0.7_ss(0,4)_strateps_greedy']}
    }
}
# Out:
# wandb: Currently logged in as: leenh050418 (leenh050418-iit-madras-foundation) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202218-bpiqompu</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/uncategorized/runs/bpiqompu' target="_blank">charmed-fog-10</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/uncategorized' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/uncategorized</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/uncategorized/runs/bpiqompu' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/uncategorized/runs/bpiqompu</a>
# Exception in thread IntMsgThr:
# Traceback (most recent call last):
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Kutral\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_run.py", line 333, in check_internal_messages
#     self._loop_check_status(
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_run.py", line 236, in _loop_check_status
#     local_handle = request()
#                    ^^^^^^^^^
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\interface\interface.py", line 1022, in deliver_internal_messages
#     return self._deliver_internal_messages(internal_message)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\interface\interface_shared.py", line 499, in _deliver_internal_messages
#     return self._deliver(record)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\interface\interface_sock.py", line 50, in _deliver
#     return self._asyncer.run(lambda: self.deliver_async(record))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\lib\asyncio_manager.py", line 133, in run
#     future = self._schedule(fn, daemon=False)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\lib\asyncio_manager.py", line 198, in _schedule
#     raise AlreadyJoinedError
# wandb.sdk.lib.asyncio_manager.AlreadyJoinedError
# Exception in thread ChkStopThr:
# Traceback (most recent call last):
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "C:\Users\Kutral\AppData\Roaming\Python\Python311\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_run.py", line 306, in check_stop_status
#     self._loop_check_status(
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_run.py", line 236, in _loop_check_status
#     local_handle = request()
#                    ^^^^^^^^^
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\interface\interface.py", line 1000, in deliver_stop_status
#     return self._deliver_stop_status(status)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\interface\interface_shared.py", line 480, in _deliver_stop_status
#     return self._deliver(record)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\interface\interface_sock.py", line 50, in _deliver
#     return self._asyncer.run(lambda: self.deliver_async(record))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\lib\asyncio_manager.py", line 133, in run
#     future = self._schedule(fn, daemon=False)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\lib\asyncio_manager.py", line 198, in _schedule
#     raise AlreadyJoinedError
# wandb.sdk.lib.asyncio_manager.AlreadyJoinedError

# %%
sweep_id = wandb.sweep(sweep_config_1, project="GPA_2_PART_A")
print("Sweep ID:", sweep_id)
# Out:
# Create sweep with ID: umdu1k6v
# Sweep URL: https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v
# Sweep ID: umdu1k6v

# %%
def train_one_sweep_run():
    wandb.init()
    cfg = wandb.config

    # setup environment
    env = create_standard_grid(transition_prob=0.7, start_state=np.array([[0,4]]))

    # pick the correct algorithm
    if cfg.algorithm == "q_learning":
        Q, returns = train_q_learning_fixed(
            env,
            episodes=1500,
            alpha=cfg.alpha,
            gamma=cfg.gamma,
            strategy=cfg.strategy,
            param=cfg.param,
            max_steps=100,
            run=wandb.run
        )
    else:
        Q, returns = train_sarsa_fixed(
            env,
            episodes=1500,
            alpha=cfg.alpha,
            gamma=cfg.gamma,
            strategy=cfg.strategy,
            param=cfg.param,
            max_steps=100,
            run=wandb.run
        )

    # Evaluate
    avg_eval = evaluate_policy(env, Q, episodes=20, max_steps=100)

    wandb.log({
        'mean_eval_return': avg_eval,
        'final_mean_reward_last50': np.mean(returns[-50:])
    })

    print(f"Run finished | α={cfg.alpha}, γ={cfg.gamma}, param={cfg.param} → avg_eval={avg_eval:.2f}")

# %%
wandb.agent(sweep_id, function=train_one_sweep_run, count=None)
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: Agent Starting Run: ukomeosi with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.7
# wandb: 	param: 0.001
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202641-ukomeosi</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ukomeosi' target="_blank">decent-sweep-1</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ukomeosi' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ukomeosi</a>
# [Q] Episode 200/1500 | Mean(Last50): -116.94
# [Q] Episode 400/1500 | Mean(Last50): -113.38
# [Q] Episode 600/1500 | Mean(Last50): -112.16
# [Q] Episode 800/1500 | Mean(Last50): -113.00
# [Q] Episode 1000/1500 | Mean(Last50): -107.60
# [Q] Episode 1200/1500 | Mean(Last50): -111.10
# [Q] Episode 1400/1500 | Mean(Last50): -107.98
# Run finished | α=0.001, γ=0.7, param=0.001 → avg_eval=-71.50
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇████</td></tr><tr><td>episode_return</td><td>▅▇▆▇▁▇▆▇▇▅▇▆▇▆▁█▇▇▇▇▇▇▆▇▆▇▇▇▇▇▇▇▇▇▇▆▆▇▆▁</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-100</td></tr><tr><td>final_mean_reward_last50</td><td>-107</td></tr><tr><td>gamma</td><td>0.7</td></tr><tr><td>mean_eval_return</td><td>-71.5</td></tr><tr><td>param</td><td>0.001</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">decent-sweep-1</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ukomeosi' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ukomeosi</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202641-ukomeosi\logs</code>
# wandb: Agent Starting Run: eu14tnfb with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.7
# wandb: 	param: 0.01
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202651-eu14tnfb</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/eu14tnfb' target="_blank">snowy-sweep-2</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/eu14tnfb' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/eu14tnfb</a>
# [Q] Episode 200/1500 | Mean(Last50): -115.16
# [Q] Episode 400/1500 | Mean(Last50): -108.74
# [Q] Episode 600/1500 | Mean(Last50): -108.06
# [Q] Episode 800/1500 | Mean(Last50): -109.44
# [Q] Episode 1000/1500 | Mean(Last50): -111.20
# [Q] Episode 1200/1500 | Mean(Last50): -103.92
# [Q] Episode 1400/1500 | Mean(Last50): -103.26
# Run finished | α=0.001, γ=0.7, param=0.01 → avg_eval=-100.00
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>episode_return</td><td>▆▆▆▆▅▆▆▅▇▆▅▆▆▆▆▅▆▁▄▆▆▅█▆▆▅▃▇▆▅▄▅▄▆▇▆▅▆▆▆</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-110</td></tr><tr><td>final_mean_reward_last50</td><td>-104.08</td></tr><tr><td>gamma</td><td>0.7</td></tr><tr><td>mean_eval_return</td><td>-100</td></tr><tr><td>param</td><td>0.01</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">snowy-sweep-2</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/eu14tnfb' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/eu14tnfb</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202651-eu14tnfb\logs</code>
# wandb: Agent Starting Run: 2gpxjvpb with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.7
# wandb: 	param: 0.05
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202708-2gpxjvpb</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/2gpxjvpb' target="_blank">dashing-sweep-3</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/2gpxjvpb' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/2gpxjvpb</a>
# [Q] Episode 200/1500 | Mean(Last50): -110.48
# [Q] Episode 400/1500 | Mean(Last50): -116.08
# [Q] Episode 600/1500 | Mean(Last50): -110.40
# [Q] Episode 800/1500 | Mean(Last50): -113.02
# [Q] Episode 1000/1500 | Mean(Last50): -104.90
# [Q] Episode 1200/1500 | Mean(Last50): -104.78
# [Q] Episode 1400/1500 | Mean(Last50): -109.96
# Run finished | α=0.001, γ=0.7, param=0.05 → avg_eval=-100.00
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇██</td></tr><tr><td>episode_return</td><td>▇▄█▄▃▃▄▃▃▃▃▄▃▄▄▄▄▂▄▃▃▂▁▄▄▃▄▄▄▄▄▄▂▃▄▄▄█▄▃</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-100</td></tr><tr><td>final_mean_reward_last50</td><td>-104.92</td></tr><tr><td>gamma</td><td>0.7</td></tr><tr><td>mean_eval_return</td><td>-100</td></tr><tr><td>param</td><td>0.05</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dashing-sweep-3</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/2gpxjvpb' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/2gpxjvpb</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202708-2gpxjvpb\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: g75qaxz5 with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.7
# wandb: 	param: 0.1
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202733-g75qaxz5</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/g75qaxz5' target="_blank">cerulean-sweep-4</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/g75qaxz5' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/g75qaxz5</a>
# [Q] Episode 200/1500 | Mean(Last50): -117.32
# [Q] Episode 400/1500 | Mean(Last50): -121.70
# [Q] Episode 600/1500 | Mean(Last50): -110.22
# [Q] Episode 800/1500 | Mean(Last50): -118.44
# [Q] Episode 1000/1500 | Mean(Last50): -121.08
# [Q] Episode 1200/1500 | Mean(Last50): -106.96
# [Q] Episode 1400/1500 | Mean(Last50): -115.48
# Run finished | α=0.001, γ=0.7, param=0.1 → avg_eval=-100.00
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇█████</td></tr><tr><td>episode_return</td><td>▅▅▃▅▅▅▅▅▅▅▅▅▅▇▂▅▅▅▂▅▅▅▅▂▅▂▅▅█▅▅▁▅▅▅▅▅█▅▅</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-100</td></tr><tr><td>final_mean_reward_last50</td><td>-116.9</td></tr><tr><td>gamma</td><td>0.7</td></tr><tr><td>mean_eval_return</td><td>-100</td></tr><tr><td>param</td><td>0.1</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cerulean-sweep-4</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/g75qaxz5' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/g75qaxz5</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202733-g75qaxz5\logs</code>
# wandb: Agent Starting Run: bpk2cv2s with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.8
# wandb: 	param: 0.001
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202745-bpk2cv2s</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/bpk2cv2s' target="_blank">vibrant-sweep-5</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/bpk2cv2s' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/bpk2cv2s</a>
# [Q] Episode 200/1500 | Mean(Last50): -114.40
# [Q] Episode 400/1500 | Mean(Last50): -121.26
# [Q] Episode 600/1500 | Mean(Last50): -112.36
# [Q] Episode 800/1500 | Mean(Last50): -113.30
# [Q] Episode 1000/1500 | Mean(Last50): -109.38
# [Q] Episode 1200/1500 | Mean(Last50): -105.24
# [Q] Episode 1400/1500 | Mean(Last50): -113.02
# Run finished | α=0.001, γ=0.8, param=0.001 → avg_eval=-100.25
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>episode_return</td><td>▅▅▅▆▁▃█▅▄▅▅▅▅▅▅▅▅▅▄▃▅▅▅▅▅▁▅▅▅▅▅▁▅▅▅▅▁▅▅▅</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-100</td></tr><tr><td>final_mean_reward_last50</td><td>-104.06</td></tr><tr><td>gamma</td><td>0.8</td></tr><tr><td>mean_eval_return</td><td>-100.25</td></tr><tr><td>param</td><td>0.001</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vibrant-sweep-5</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/bpk2cv2s' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/bpk2cv2s</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202745-bpk2cv2s\logs</code>
# wandb: Agent Starting Run: hfgy5hqf with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.8
# wandb: 	param: 0.01
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202802-hfgy5hqf</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/hfgy5hqf' target="_blank">fast-sweep-6</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/hfgy5hqf' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/hfgy5hqf</a>
# [Q] Episode 200/1500 | Mean(Last50): -119.18
# [Q] Episode 400/1500 | Mean(Last50): -115.40
# [Q] Episode 600/1500 | Mean(Last50): -111.26
# [Q] Episode 800/1500 | Mean(Last50): -110.02
# [Q] Episode 1000/1500 | Mean(Last50): -112.46
# [Q] Episode 1200/1500 | Mean(Last50): -110.70
# [Q] Episode 1400/1500 | Mean(Last50): -114.30
# Run finished | α=0.001, γ=0.8, param=0.01 → avg_eval=-100.00
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>episode_return</td><td>▆▇▆▆▄▁▇▄█▁▅▇▆▆▆▆▄▆▆▆▆▆▆▁▆▆▆▅▆▆▆▇▅▇▆▆▅▆▆▅</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-110</td></tr><tr><td>final_mean_reward_last50</td><td>-105.4</td></tr><tr><td>gamma</td><td>0.8</td></tr><tr><td>mean_eval_return</td><td>-100</td></tr><tr><td>param</td><td>0.01</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fast-sweep-6</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/hfgy5hqf' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/hfgy5hqf</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202802-hfgy5hqf\logs</code>
# wandb: Agent Starting Run: usn7dvks with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.8
# wandb: 	param: 0.05
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202817-usn7dvks</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/usn7dvks' target="_blank">comfy-sweep-7</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/usn7dvks' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/usn7dvks</a>
# [Q] Episode 200/1500 | Mean(Last50): -123.48
# [Q] Episode 400/1500 | Mean(Last50): -114.56
# [Q] Episode 600/1500 | Mean(Last50): -116.14
# [Q] Episode 800/1500 | Mean(Last50): -117.94
# [Q] Episode 1000/1500 | Mean(Last50): -115.88
# [Q] Episode 1200/1500 | Mean(Last50): -111.54
# [Q] Episode 1400/1500 | Mean(Last50): -115.52
# Run finished | α=0.001, γ=0.8, param=0.05 → avg_eval=-109.00
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇█</td></tr><tr><td>episode_return</td><td>▅▅▁▅▅▁▅▄▅▄▅▅▅▇▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅█▅▅▅▅▅▅▅▅▁</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-100</td></tr><tr><td>final_mean_reward_last50</td><td>-112.42</td></tr><tr><td>gamma</td><td>0.8</td></tr><tr><td>mean_eval_return</td><td>-109</td></tr><tr><td>param</td><td>0.05</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">comfy-sweep-7</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/usn7dvks' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/usn7dvks</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202817-usn7dvks\logs</code>
# wandb: Agent Starting Run: xq7v94gs with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.8
# wandb: 	param: 0.1
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202828-xq7v94gs</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/xq7v94gs' target="_blank">kind-sweep-8</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/xq7v94gs' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/xq7v94gs</a>
# [Q] Episode 200/1500 | Mean(Last50): -119.12
# [Q] Episode 400/1500 | Mean(Last50): -127.32
# [Q] Episode 600/1500 | Mean(Last50): -115.70
# [Q] Episode 800/1500 | Mean(Last50): -116.32
# [Q] Episode 1000/1500 | Mean(Last50): -113.04
# [Q] Episode 1200/1500 | Mean(Last50): -117.92
# [Q] Episode 1400/1500 | Mean(Last50): -106.54
# Run finished | α=0.001, γ=0.8, param=0.1 → avg_eval=-100.00
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>episode_return</td><td>▇▇▇▇▇▇▄▇▇▇▇▇▇▇█▃▇▇▇▁▇▇█▇█▇▇▇▄▄▇▇▇▆▇▄▇▇▇█</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-78</td></tr><tr><td>final_mean_reward_last50</td><td>-115.68</td></tr><tr><td>gamma</td><td>0.8</td></tr><tr><td>mean_eval_return</td><td>-100</td></tr><tr><td>param</td><td>0.1</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">kind-sweep-8</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/xq7v94gs' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/xq7v94gs</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202828-xq7v94gs\logs</code>
# wandb: Agent Starting Run: ssap5i4b with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.9
# wandb: 	param: 0.001
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202839-ssap5i4b</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ssap5i4b' target="_blank">dashing-sweep-9</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ssap5i4b' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ssap5i4b</a>
# [Q] Episode 200/1500 | Mean(Last50): -111.64
# [Q] Episode 400/1500 | Mean(Last50): -113.28
# [Q] Episode 600/1500 | Mean(Last50): -112.00
# [Q] Episode 800/1500 | Mean(Last50): -110.56
# [Q] Episode 1000/1500 | Mean(Last50): -110.62
# [Q] Episode 1200/1500 | Mean(Last50): -106.80
# [Q] Episode 1400/1500 | Mean(Last50): -109.58
# Run finished | α=0.001, γ=0.9, param=0.001 → avg_eval=-100.00
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>episode_return</td><td>▆▇▁▆▆▆▆▂▆▆▇▆▆▅▆▅▆▆█▆▂▆█▆▇▆▆▆▆▆▆▆▆▃▆▆▅▆▆▆</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-86</td></tr><tr><td>final_mean_reward_last50</td><td>-105.14</td></tr><tr><td>gamma</td><td>0.9</td></tr><tr><td>mean_eval_return</td><td>-100</td></tr><tr><td>param</td><td>0.001</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dashing-sweep-9</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ssap5i4b' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ssap5i4b</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202839-ssap5i4b\logs</code>
# wandb: Agent Starting Run: w29muwt8 with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.9
# wandb: 	param: 0.01
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202855-w29muwt8</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/w29muwt8' target="_blank">frosty-sweep-10</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/w29muwt8' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/w29muwt8</a>
# [Q] Episode 200/1500 | Mean(Last50): -116.04
# [Q] Episode 400/1500 | Mean(Last50): -109.22
# [Q] Episode 600/1500 | Mean(Last50): -119.64
# [Q] Episode 800/1500 | Mean(Last50): -106.48
# [Q] Episode 1000/1500 | Mean(Last50): -105.58
# [Q] Episode 1200/1500 | Mean(Last50): -111.64
# [Q] Episode 1400/1500 | Mean(Last50): -109.70
# Run finished | α=0.001, γ=0.9, param=0.01 → avg_eval=-100.25
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▃▃▄▄▄▄▅▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>episode_return</td><td>▅▆▁▆▆▅▆▄▆▆▅▅█▅▆▆▆▄▆▆▁▆▆▅▆▅▅▆▆▆▆▆▆▆▅▁▆▅▆▆</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-115</td></tr><tr><td>final_mean_reward_last50</td><td>-115.44</td></tr><tr><td>gamma</td><td>0.9</td></tr><tr><td>mean_eval_return</td><td>-100.25</td></tr><tr><td>param</td><td>0.01</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">frosty-sweep-10</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/w29muwt8' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/w29muwt8</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202855-w29muwt8\logs</code>
# wandb: Agent Starting Run: r0h12pdy with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.9
# wandb: 	param: 0.05
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202917-r0h12pdy</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/r0h12pdy' target="_blank">valiant-sweep-11</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/r0h12pdy' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/r0h12pdy</a>
# [Q] Episode 200/1500 | Mean(Last50): -119.22
# [Q] Episode 400/1500 | Mean(Last50): -111.42
# [Q] Episode 600/1500 | Mean(Last50): -104.12
# [Q] Episode 800/1500 | Mean(Last50): -112.72
# [Q] Episode 1000/1500 | Mean(Last50): -110.42
# [Q] Episode 1200/1500 | Mean(Last50): -112.84
# [Q] Episode 1400/1500 | Mean(Last50): -106.74
# Run finished | α=0.001, γ=0.9, param=0.05 → avg_eval=-100.00
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇█</td></tr><tr><td>episode_return</td><td>▅▄▄▆▅▅█▆▆▁▅▅▅▆▆▆▆▆▆▆▅▅▆▅▆▆▅▅▆▆▂▁▆▇▆▅▅▅▇▆</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-100</td></tr><tr><td>final_mean_reward_last50</td><td>-108.4</td></tr><tr><td>gamma</td><td>0.9</td></tr><tr><td>mean_eval_return</td><td>-100</td></tr><tr><td>param</td><td>0.05</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">valiant-sweep-11</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/r0h12pdy' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/r0h12pdy</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202917-r0h12pdy\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: v5gjfsa2 with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 0.9
# wandb: 	param: 0.1
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_202943-v5gjfsa2</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/v5gjfsa2' target="_blank">fast-sweep-12</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/v5gjfsa2' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/v5gjfsa2</a>
# [Q] Episode 200/1500 | Mean(Last50): -109.82
# [Q] Episode 400/1500 | Mean(Last50): -120.04
# [Q] Episode 600/1500 | Mean(Last50): -111.46
# [Q] Episode 800/1500 | Mean(Last50): -112.28
# [Q] Episode 1000/1500 | Mean(Last50): -117.66
# [Q] Episode 1200/1500 | Mean(Last50): -113.18
# [Q] Episode 1400/1500 | Mean(Last50): -111.16
# Run finished | α=0.001, γ=0.9, param=0.1 → avg_eval=-100.00
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▁▁▂▂▂▃▃▃▃▃▃▃▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>episode_return</td><td>▆▁▅▆▆▆▆▁▃▆▆█▆▆▆▅▆▆▃▆▆▆▁▆▆▁▅▆▆▆▄▁▆▆▆▆▇▆▁▆</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>0.001</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-100</td></tr><tr><td>final_mean_reward_last50</td><td>-110.08</td></tr><tr><td>gamma</td><td>0.9</td></tr><tr><td>mean_eval_return</td><td>-100</td></tr><tr><td>param</td><td>0.1</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fast-sweep-12</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/v5gjfsa2' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/v5gjfsa2</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_202943-v5gjfsa2\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: y9tbdqrl with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 0.001
# ...
#  View run <strong style="color:#cdcd00">absurd-sweep-61</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/9zya26km' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/9zya26km</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_204350-9zya26km\logs</code>
# wandb: Agent Starting Run: ogsu3qd8 with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 1
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 1
# wandb: 	param: 0.01
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_204408-ogsu3qd8</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ogsu3qd8' target="_blank">valiant-sweep-62</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ogsu3qd8' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ogsu3qd8</a>
# [Q] Episode 200/1500 | Mean(Last50): -39.00
# [Q] Episode 400/1500 | Mean(Last50): -50.34
# [Q] Episode 600/1500 | Mean(Last50): -45.60
# [Q] Episode 800/1500 | Mean(Last50): -35.10
# [Q] Episode 1000/1500 | Mean(Last50): -33.10
# [Q] Episode 1200/1500 | Mean(Last50): -34.54
# [Q] Episode 1400/1500 | Mean(Last50): -31.26
# Run finished | α=1, γ=1, param=0.01 → avg_eval=-54.05
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▁▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇█████</td></tr><tr><td>episode_return</td><td>▁██▇███▅██▆▆█▇█▇▆███▇██▇█▇█▇▇█▇█▅▄███▆▇█</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>1</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-115</td></tr><tr><td>final_mean_reward_last50</td><td>-55.5</td></tr><tr><td>gamma</td><td>1</td></tr><tr><td>mean_eval_return</td><td>-54.05</td></tr><tr><td>param</td><td>0.01</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">valiant-sweep-62</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ogsu3qd8' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/ogsu3qd8</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_204408-ogsu3qd8\logs</code>
# wandb: Agent Starting Run: 64lbrgsf with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 1
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 1
# wandb: 	param: 0.05
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_204423-64lbrgsf</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/64lbrgsf' target="_blank">misty-sweep-63</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/64lbrgsf' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/64lbrgsf</a>
# [Q] Episode 200/1500 | Mean(Last50): -74.52
# [Q] Episode 400/1500 | Mean(Last50): -53.64
# [Q] Episode 600/1500 | Mean(Last50): -62.18
# [Q] Episode 800/1500 | Mean(Last50): -47.78
# [Q] Episode 1000/1500 | Mean(Last50): -56.32
# [Q] Episode 1200/1500 | Mean(Last50): -38.84
# [Q] Episode 1400/1500 | Mean(Last50): -37.96
# Run finished | α=1, γ=1, param=0.05 → avg_eval=-33.80
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>episode_return</td><td>██▅▇███▇▆█▇█▆█▇▁▇██▇▇█▆▅▇██▇█▅▇█████▇▇▆▇</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>1</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-31</td></tr><tr><td>final_mean_reward_last50</td><td>-38.16</td></tr><tr><td>gamma</td><td>1</td></tr><tr><td>mean_eval_return</td><td>-33.8</td></tr><tr><td>param</td><td>0.05</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">misty-sweep-63</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/64lbrgsf' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/64lbrgsf</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_204423-64lbrgsf\logs</code>
# wandb: Agent Starting Run: gb0d4seq with config:
# wandb: 	algorithm: q_learning
# wandb: 	alpha: 1
# wandb: 	env_name: std_q_tp0.7_ss(0,4)_strateps_greedy
# wandb: 	gamma: 1
# wandb: 	param: 0.1
# wandb: 	strategy: eps_greedy
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>d:\...SEM5\RL\GPA_2_new\Grid-World-Environment-main\wandb\run-20251103_204440-gb0d4seq</code>
# Syncing run <strong><a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/gb0d4seq' target="_blank">stoic-sweep-64</a></strong> to <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View project at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a>
#  View sweep at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/sweeps/umdu1k6v</a>
#  View run at <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/gb0d4seq' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/gb0d4seq</a>
# [Q] Episode 200/1500 | Mean(Last50): -70.48
# [Q] Episode 400/1500 | Mean(Last50): -67.44
# [Q] Episode 600/1500 | Mean(Last50): -56.10
# [Q] Episode 800/1500 | Mean(Last50): -68.96
# [Q] Episode 1000/1500 | Mean(Last50): -84.98
# [Q] Episode 1200/1500 | Mean(Last50): -62.56
# [Q] Episode 1400/1500 | Mean(Last50): -52.06
# Run finished | α=1, γ=1, param=0.1 → avg_eval=-77.85
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>episode</td><td>▁▁▁▁▁▂▂▂▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>episode_return</td><td>▇▁▃▆▆▇▆▆█▇█▇▆▃▇▆▆▇▄█▆▇▆▇▇█▆▆▇▇█▆▇█▇▇██▅▇</td></tr><tr><td>final_mean_reward_last50</td><td>▁</td></tr><tr><td>gamma</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>mean_eval_return</td><td>▁</td></tr><tr><td>param</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>algorithm</td><td>Q-learning</td></tr><tr><td>alpha</td><td>1</td></tr><tr><td>episode</td><td>1499</td></tr><tr><td>episode_return</td><td>-59</td></tr><tr><td>final_mean_reward_last50</td><td>-58.58</td></tr><tr><td>gamma</td><td>1</td></tr><tr><td>mean_eval_return</td><td>-77.85</td></tr><tr><td>param</td><td>0.1</td></tr><tr><td>strategy</td><td>eps_greedy</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stoic-sweep-64</strong> at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/gb0d4seq' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A/runs/gb0d4seq</a><br> View project at: <a href='https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A' target="_blank">https://wandb.ai/leenh050418-iit-madras-foundation/GPA_2_PART_A</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20251103_204440-gb0d4seq\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x00000296B1874890>> (for post_run_cell), with arguments args (<ExecutionResult object at 296b188cc10, execution_count=10 error_before_exec=None error_in_exec=None info=<ExecutionInfo object at 296b186c490, raw_cell="wandb.agent(sweep_id, function=train_one_sweep_run.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/d%3A/...SEM5/RL/GPA_2_new/Grid-World-Environment-main/PART_A.ipynb#X22sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# AlreadyJoinedError                        Traceback (most recent call last)
# File c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\wandb_init.py:596, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     593     return
#     595 self._logger.info("resuming backend")
# --> 596 self.backend.interface.publish_resume()
#
# File c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\interface\interface.py:826, in InterfaceBase.publish_resume(self)
#     824 def publish_resume(self) -> None:
#     825     resume = pb.ResumeRequest()
# --> 826     self._publish_resume(resume)
#
# File c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\interface\interface_shared.py:334, in InterfaceShared._publish_resume(self, resume)
#     332 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     333     rec = self._make_request(resume=resume)
# --> 334     self._publish(rec)
#
# File c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\interface\interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\lib\asyncio_manager.py:133, in AsyncioManager.run(self, fn)
#     130 if threading.current_thread().ident == self._thread.ident:
#     131     raise ValueError("Cannot use run() inside async loop.")
# --> 133 future = self._schedule(fn, daemon=False)
#     135 try:
#     136     return future.result()
#
# File c:\Users\Kutral\AppData\Local\Programs\Python\Python311\Lib\site-packages\wandb\sdk\lib\asyncio_manager.py:198, in AsyncioManager._schedule(self, fn, daemon, name)
#     196 with self._lock:
#     197     if self._joined:
# --> 198         raise AlreadyJoinedError
#     200     if not daemon:
#     201         self._remaining_tasks += 1
#
# AlreadyJoinedError:
